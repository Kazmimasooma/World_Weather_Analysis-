# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\masoomakazmi\.conda\envs\pythondata\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\masoomakazmi\.conda\envs\pythondata\lib\site-packages (from citipy) (0.16)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add thelatitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description" : city_description                          
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | clyde river
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | havelock
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | lasa
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | minot
# Processing Record 15 of Set 1 | rawson
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | santa rita
# Processing Record 23 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | bluff
# Processing Record 29 of Set 1 | kavieng
# Processing Record 30 of Set 1 | shenandoah
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 1 | half moon bay
# Processing Record 36 of Set 1 | pangai
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | khash
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | koumac
# Processing Record 41 of Set 1 | san carlos de bariloche
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | punta cardon
# Processing Record 44 of Set 1 | kanker
# Processing Record 45 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | gotsu
# Processing Record 2 of Set 2 | faanui
# Processing Record 3 of Set 2 | bombay
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | beyneu
# Processing Record 6 of Set 2 | catamarca
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | ahipara
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | mumford
# Processing Record 11 of Set 2 | les cayes
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | xining
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | salalah
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | lubaczow
# Processing Record 22 of Set 2 | sestri levante
# Processing Record 23 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 2 | port alfred
# Processing Record 25 of Set 2 | lucea
# Processing Record 26 of Set 2 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 2 | springdale
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | reyes
# Processing Record 30 of Set 2 | dunda
# Processing Record 31 of Set 2 | sakakah
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | griffith
# Processing Record 34 of Set 2 | shenkursk
# Processing Record 35 of Set 2 | victoria
# Processing Record 36 of Set 2 | campoverde
# Processing Record 37 of Set 2 | rapar
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | egvekinot
# Processing Record 40 of Set 2 | nishihara
# Processing Record 41 of Set 2 | dire
# Processing Record 42 of Set 2 | salinas
# Processing Record 43 of Set 2 | grindavik
# Processing Record 44 of Set 2 | shumskiy
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | otjiwarongo
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | bandarbeyla
# Processing Record 49 of Set 2 | aquin
# Processing Record 50 of Set 2 | whitehorse
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | awjilah
# Processing Record 3 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 4 of Set 3 | tigzirt
# Processing Record 5 of Set 3 | kristinehamn
# Processing Record 6 of Set 3 | mareeba
# Processing Record 7 of Set 3 | olafsvik
# Processing Record 8 of Set 3 | necochea
# Processing Record 9 of Set 3 | paso de carrasco
# Processing Record 10 of Set 3 | grand gaube
# Processing Record 11 of Set 3 | flin flon
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | kieta
# Processing Record 15 of Set 3 | razole
# Processing Record 16 of Set 3 | aranos
# Processing Record 17 of Set 3 | gat
# Processing Record 18 of Set 3 | hofn
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | bom jesus
# Processing Record 21 of Set 3 | champa
# Processing Record 22 of Set 3 | ibra
# Processing Record 23 of Set 3 | arlit
# Processing Record 24 of Set 3 | kassala
# Processing Record 25 of Set 3 | marrakesh
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | qaanaaq
# Processing Record 29 of Set 3 | nioro
# Processing Record 30 of Set 3 | taree
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 3 | laguna
# Processing Record 34 of Set 3 | tubuala
# Processing Record 35 of Set 3 | vao
# Processing Record 36 of Set 3 | fukuchiyama
# Processing Record 37 of Set 3 | brits
# Processing Record 38 of Set 3 | alyangula
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | diffa
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | melfi
# Processing Record 44 of Set 3 | gold coast
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 3 | vaini
# Processing Record 48 of Set 3 | dyurtyuli
# Processing Record 49 of Set 3 | hovd
# Processing Record 50 of Set 3 | margate
# Processing Record 1 of Set 4 | xai-xai
# Processing Record 2 of Set 4 | taft
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | aloleng
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | blagoyevo
# Processing Record 7 of Set 4 | bonavista
# Processing Record 8 of Set 4 | marzuq
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | doha
# Processing Record 11 of Set 4 | novikovo
# Processing Record 12 of Set 4 | islamkot
# Processing Record 13 of Set 4 | upernavik
# Processing Record 14 of Set 4 | mount isa
# Processing Record 15 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 4 | lashio
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | lima
# Processing Record 19 of Set 4 | vizinga
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | atar
# Processing Record 23 of Set 4 | poum
# Processing Record 24 of Set 4 | mahebourg
# Processing Record 25 of Set 4 | yakeshi
# Processing Record 26 of Set 4 | east london
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | christchurch
# Processing Record 29 of Set 4 | nanning
# Processing Record 30 of Set 4 | oranjemund
# Processing Record 31 of Set 4 | veraval
# Processing Record 32 of Set 4 | thyboron
# Processing Record 33 of Set 4 | prieska
# Processing Record 34 of Set 4 | paamiut
# Processing Record 35 of Set 4 | mendi
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | bethel
# Processing Record 38 of Set 4 | aransas pass
# Processing Record 39 of Set 4 | buraydah
# Processing Record 40 of Set 4 | litovko
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | sonoma
# Processing Record 43 of Set 4 | fukue
# Processing Record 44 of Set 4 | nyimba
# Processing Record 45 of Set 4 | faya
# Processing Record 46 of Set 4 | ulaangom
# Processing Record 47 of Set 4 | longyearbyen
# Processing Record 48 of Set 4 | malaia
# Processing Record 49 of Set 4 | ukiah
# Processing Record 50 of Set 4 | balikpapan
# Processing Record 1 of Set 5 | molina
# Processing Record 2 of Set 5 | tank
# Processing Record 3 of Set 5 | kudahuvadhoo
# Processing Record 4 of Set 5 | lusambo
# Processing Record 5 of Set 5 | bengkulu
# Processing Record 6 of Set 5 | xianshuigu
# Processing Record 7 of Set 5 | olbia
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | constitucion
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 12 of Set 5 | libenge
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | hualmay
# Processing Record 15 of Set 5 | choma
# Processing Record 16 of Set 5 | krasnoselkup
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | fairbanks
# Processing Record 19 of Set 5 | chengde
# Processing Record 20 of Set 5 | thompson
# Processing Record 21 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 5 | codrington
# Processing Record 23 of Set 5 | kawalu
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | escarcega
# Processing Record 26 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 5 | ketchikan
# Processing Record 28 of Set 5 | waddan
# Processing Record 29 of Set 5 | cayambe
# Processing Record 30 of Set 5 | formosa
# Processing Record 31 of Set 5 | vanimo
# Processing Record 32 of Set 5 | nueva italia
# Processing Record 33 of Set 5 | bariri
# Processing Record 34 of Set 5 | rongcheng
# Processing Record 35 of Set 5 | flinders
# Processing Record 36 of Set 5 | ljungby
# Processing Record 37 of Set 5 | evensk
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | coxim
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | niltepec
# Processing Record 42 of Set 5 | port hardy
# Processing Record 43 of Set 5 | noumea
# Processing Record 44 of Set 5 | patitirion
# Processing Record 45 of Set 5 | nantucket
# Processing Record 46 of Set 5 | inirida
# Processing Record 47 of Set 5 | svolvaer
# Processing Record 48 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 49 of Set 5 | mbandaka
# Processing Record 50 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 6 | huangmei
# Processing Record 2 of Set 6 | asyut
# Processing Record 3 of Set 6 | emirdag
# Processing Record 4 of Set 6 | cape coast
# Processing Record 5 of Set 6 | izumo
# Processing Record 6 of Set 6 | keti bandar
# Processing Record 7 of Set 6 | platanos
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | ostrovnoy
# Processing Record 10 of Set 6 | san quintin
# Processing Record 11 of Set 6 | carnot
# Processing Record 12 of Set 6 | marks
# Processing Record 13 of Set 6 | moussoro
# Processing Record 14 of Set 6 | asau
# Processing Record 15 of Set 6 | aitape
# Processing Record 16 of Set 6 | fartura
# Processing Record 17 of Set 6 | comodoro rivadavia
# Processing Record 18 of Set 6 | dingle
# Processing Record 19 of Set 6 | saint-pierre
# Processing Record 20 of Set 6 | komsomolskiy
# Processing Record 21 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | coruripe
# Processing Record 25 of Set 6 | san ignacio
# Processing Record 26 of Set 6 | souillac
# Processing Record 27 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 28 of Set 6 | marystown
# Processing Record 29 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 6 | luanda
# Processing Record 31 of Set 6 | abu dhabi
# Processing Record 32 of Set 6 | olutanga
# Processing Record 33 of Set 6 | balabac
# Processing Record 34 of Set 6 | sola
# Processing Record 35 of Set 6 | yanliang
# Processing Record 36 of Set 6 | salihorsk
# Processing Record 37 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 6 | kruisfontein
# Processing Record 39 of Set 6 | koungou
# Processing Record 40 of Set 6 | teguldet
# Processing Record 41 of Set 6 | charters towers
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | loreto
# Processing Record 44 of Set 6 | pavda
# City not found. Skipping...
# Processing Record 45 of Set 6 | chiang klang
# Processing Record 46 of Set 6 | mormugao
# Processing Record 47 of Set 6 | sabzevar
# Processing Record 48 of Set 6 | hasaki
# Processing Record 49 of Set 6 | basco
# Processing Record 50 of Set 6 | cidreira
# Processing Record 1 of Set 7 | ziarat
# Processing Record 2 of Set 7 | viedma
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | severo-yeniseyskiy
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | lorengau
# Processing Record 8 of Set 7 | filingue
# Processing Record 9 of Set 7 | shimoda
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | broome
# Processing Record 12 of Set 7 | mersing
# Processing Record 13 of Set 7 | chapada dos guimaraes
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 16 of Set 7 | letychiv
# Processing Record 17 of Set 7 | uberaba
# Processing Record 18 of Set 7 | escanaba
# Processing Record 19 of Set 7 | katima mulilo
# Processing Record 20 of Set 7 | nimaparha
# Processing Record 21 of Set 7 | maniitsoq
# Processing Record 22 of Set 7 | camargo
# Processing Record 23 of Set 7 | quatre cocos
# Processing Record 24 of Set 7 | nieuw amsterdam
# Processing Record 25 of Set 7 | the pas
# Processing Record 26 of Set 7 | krylovskaya
# Processing Record 27 of Set 7 | la ronge
# Processing Record 28 of Set 7 | hefei
# Processing Record 29 of Set 7 | chihu
# City not found. Skipping...
# Processing Record 30 of Set 7 | verkh-usugli
# Processing Record 31 of Set 7 | ponca city
# Processing Record 32 of Set 7 | lincoln
# Processing Record 33 of Set 7 | kuala terengganu
# Processing Record 34 of Set 7 | vardo
# Processing Record 35 of Set 7 | emba
# Processing Record 36 of Set 7 | aripuana
# Processing Record 37 of Set 7 | entre rios
# Processing Record 38 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 7 | turukhansk
# Processing Record 40 of Set 7 | provideniya
# Processing Record 41 of Set 7 | bayan
# Processing Record 42 of Set 7 | amahai
# Processing Record 43 of Set 7 | sosnovo-ozerskoye
# Processing Record 44 of Set 7 | coquimbo
# Processing Record 45 of Set 7 | burnie
# Processing Record 46 of Set 7 | moa
# Processing Record 47 of Set 7 | misratah
# Processing Record 48 of Set 7 | kavaratti
# Processing Record 49 of Set 7 | vanino
# Processing Record 50 of Set 7 | stykkisholmur
# Processing Record 1 of Set 8 | tura
# Processing Record 2 of Set 8 | tateyama
# Processing Record 3 of Set 8 | garoua
# Processing Record 4 of Set 8 | eureka
# Processing Record 5 of Set 8 | san patricio
# Processing Record 6 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 8 | tongliao
# Processing Record 8 of Set 8 | bellmead
# Processing Record 9 of Set 8 | rabo de peixe
# Processing Record 10 of Set 8 | kampot
# Processing Record 11 of Set 8 | pailon
# Processing Record 12 of Set 8 | college
# Processing Record 13 of Set 8 | saint-augustin
# Processing Record 14 of Set 8 | kaitangata
# Processing Record 15 of Set 8 | chokurdakh
# Processing Record 16 of Set 8 | tabora
# Processing Record 17 of Set 8 | alice springs
# Processing Record 18 of Set 8 | kapan
# Processing Record 19 of Set 8 | vuktyl
# Processing Record 20 of Set 8 | bilma
# Processing Record 21 of Set 8 | saint anthony
# Processing Record 22 of Set 8 | hobyo
# Processing Record 23 of Set 8 | yinchuan
# Processing Record 24 of Set 8 | tuatapere
# Processing Record 25 of Set 8 | san juan
# Processing Record 26 of Set 8 | pomabamba
# Processing Record 27 of Set 8 | bandipur
# Processing Record 28 of Set 8 | cozumel
# Processing Record 29 of Set 8 | lavrentiya
# Processing Record 30 of Set 8 | preston
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | bambous virieux
# Processing Record 33 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 8 | morros
# Processing Record 35 of Set 8 | vrangel
# Processing Record 36 of Set 8 | labuhan
# Processing Record 37 of Set 8 | dehloran
# Processing Record 38 of Set 8 | airai
# Processing Record 39 of Set 8 | narsaq
# Processing Record 40 of Set 8 | bagdarin
# Processing Record 41 of Set 8 | sangar
# Processing Record 42 of Set 8 | mgachi
# Processing Record 43 of Set 8 | muskegon
# Processing Record 44 of Set 8 | rio de janeiro
# Processing Record 45 of Set 8 | imphal
# Processing Record 46 of Set 8 | sugod
# Processing Record 47 of Set 8 | high level
# Processing Record 48 of Set 8 | mae ramat
# Processing Record 49 of Set 8 | kishapu
# Processing Record 50 of Set 8 | chon daen
# Processing Record 1 of Set 9 | natal
# Processing Record 2 of Set 9 | ancud
# Processing Record 3 of Set 9 | flagstaff
# Processing Record 4 of Set 9 | umuarama
# Processing Record 5 of Set 9 | santa ines
# Processing Record 6 of Set 9 | paralimni
# Processing Record 7 of Set 9 | joshimath
# Processing Record 8 of Set 9 | leningradskiy
# Processing Record 9 of Set 9 | tingo maria
# Processing Record 10 of Set 9 | juneau
# Processing Record 11 of Set 9 | ust-kishert
# Processing Record 12 of Set 9 | itaqui
# Processing Record 13 of Set 9 | sovetsk
# Processing Record 14 of Set 9 | kirovsk
# Processing Record 15 of Set 9 | del gallego
# Processing Record 16 of Set 9 | ribeirao branco
# Processing Record 17 of Set 9 | marsabit
# Processing Record 18 of Set 9 | sayyan
# Processing Record 19 of Set 9 | chenzhou
# Processing Record 20 of Set 9 | cumana
# Processing Record 21 of Set 9 | nova olimpia
# Processing Record 22 of Set 9 | adrar
# Processing Record 23 of Set 9 | porto velho
# Processing Record 24 of Set 9 | benguela
# Processing Record 25 of Set 9 | pelym
# Processing Record 26 of Set 9 | porto novo
# Processing Record 27 of Set 9 | lincolnton
# Processing Record 28 of Set 9 | senneterre
# Processing Record 29 of Set 9 | belmonte
# Processing Record 30 of Set 9 | kwinana
# Processing Record 31 of Set 9 | kurilsk
# Processing Record 32 of Set 9 | sorland
# Processing Record 33 of Set 9 | qaqortoq
# Processing Record 34 of Set 9 | dandong
# Processing Record 35 of Set 9 | anyama
# Processing Record 36 of Set 9 | sinnamary
# Processing Record 37 of Set 9 | alice
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | san ramon
# Processing Record 41 of Set 9 | port lincoln
# Processing Record 42 of Set 9 | boa esperanca do sul
# Processing Record 43 of Set 9 | moron
# Processing Record 44 of Set 9 | leh
# Processing Record 45 of Set 9 | port augusta
# Processing Record 46 of Set 9 | mirabad
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | baoqing
# Processing Record 49 of Set 9 | gogrial
# Processing Record 50 of Set 9 | inuvik
# Processing Record 1 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 2 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 3 of Set 10 | araouane
# Processing Record 4 of Set 10 | trairi
# Processing Record 5 of Set 10 | buritizeiro
# Processing Record 6 of Set 10 | miri
# Processing Record 7 of Set 10 | oussouye
# Processing Record 8 of Set 10 | nome
# Processing Record 9 of Set 10 | santa maria
# Processing Record 10 of Set 10 | ambanja
# Processing Record 11 of Set 10 | chicama
# Processing Record 12 of Set 10 | guerrero negro
# Processing Record 13 of Set 10 | port blair
# Processing Record 14 of Set 10 | nemuro
# Processing Record 15 of Set 10 | gladstone
# Processing Record 16 of Set 10 | aberdeen
# Processing Record 17 of Set 10 | shelburne
# Processing Record 18 of Set 10 | samarai
# Processing Record 19 of Set 10 | riyadh
# Processing Record 20 of Set 10 | sento se
# City not found. Skipping...
# Processing Record 21 of Set 10 | am timan
# Processing Record 22 of Set 10 | talcahuano
# Processing Record 23 of Set 10 | seoul
# Processing Record 24 of Set 10 | omama
# Processing Record 25 of Set 10 | storsteinnes
# Processing Record 26 of Set 10 | zhezkazgan
# Processing Record 27 of Set 10 | amarante do maranhao
# Processing Record 28 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 10 | imbituba
# Processing Record 30 of Set 10 | kuusamo
# Processing Record 31 of Set 10 | rocha
# Processing Record 32 of Set 10 | inverurie
# Processing Record 33 of Set 10 | atambua
# Processing Record 34 of Set 10 | eyl
# Processing Record 35 of Set 10 | bad sankt leonhard
# City not found. Skipping...
# Processing Record 36 of Set 10 | banjar
# Processing Record 37 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 38 of Set 10 | lodja
# Processing Record 39 of Set 10 | port hawkesbury
# Processing Record 40 of Set 10 | teya
# Processing Record 41 of Set 10 | te anau
# Processing Record 42 of Set 10 | voh
# Processing Record 43 of Set 10 | zalari
# Processing Record 44 of Set 10 | mayakonda
# Processing Record 45 of Set 10 | carlos chagas
# Processing Record 46 of Set 10 | morondava
# Processing Record 47 of Set 10 | aswan
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | clarence town
# Processing Record 50 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 1 of Set 11 | yerbogachen
# Processing Record 2 of Set 11 | isla vista
# Processing Record 3 of Set 11 | daru
# Processing Record 4 of Set 11 | rumes
# Processing Record 5 of Set 11 | mitu
# Processing Record 6 of Set 11 | sechura
# Processing Record 7 of Set 11 | arman
# Processing Record 8 of Set 11 | mount gambier
# Processing Record 9 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 10 of Set 11 | killybegs
# Processing Record 11 of Set 11 | susanville
# Processing Record 12 of Set 11 | pinega
# Processing Record 13 of Set 11 | qujing
# Processing Record 14 of Set 11 | ler
# Processing Record 15 of Set 11 | bluefields
# Processing Record 16 of Set 11 | rudolstadt
# Processing Record 17 of Set 11 | empalme
# Processing Record 18 of Set 11 | agadez
# Processing Record 19 of Set 11 | cabo san lucas
# Processing Record 20 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 21 of Set 11 | tanout
# Processing Record 22 of Set 11 | sibu
# Processing Record 23 of Set 11 | rio grande
# Processing Record 24 of Set 11 | ekibastuz
# Processing Record 25 of Set 11 | almaznyy
# Processing Record 26 of Set 11 | kenai
# Processing Record 27 of Set 11 | vila velha
# Processing Record 28 of Set 11 | kijang
# Processing Record 29 of Set 11 | tautira
# Processing Record 30 of Set 11 | tocopilla
# Processing Record 31 of Set 11 | wanning
# Processing Record 32 of Set 11 | serov
# Processing Record 33 of Set 11 | payakumbuh
# Processing Record 34 of Set 11 | malanje
# Processing Record 35 of Set 11 | troina
# Processing Record 36 of Set 11 | palu
# Processing Record 37 of Set 11 | bereza
# Processing Record 38 of Set 11 | chapais
# Processing Record 39 of Set 11 | alihe
# Processing Record 40 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 41 of Set 11 | port keats
# Processing Record 42 of Set 11 | torrington
# Processing Record 43 of Set 11 | nipawin
# Processing Record 44 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 11 | brigantine
# Processing Record 46 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 47 of Set 11 | marsa matruh
# Processing Record 48 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 11 | omsukchan
# Processing Record 50 of Set 11 | ekhabi
# Processing Record 1 of Set 12 | mattawa
# Processing Record 2 of Set 12 | myitkyina
# Processing Record 3 of Set 12 | mamallapuram
# Processing Record 4 of Set 12 | babushkin
# Processing Record 5 of Set 12 | lensk
# Processing Record 6 of Set 12 | broken hill
# Processing Record 7 of Set 12 | paranhos
# Processing Record 8 of Set 12 | pitimbu
# Processing Record 9 of Set 12 | inzhavino
# Processing Record 10 of Set 12 | neftekamsk
# Processing Record 11 of Set 12 | panaba
# Processing Record 12 of Set 12 | atagay
# Processing Record 13 of Set 12 | ola
# Processing Record 14 of Set 12 | raudeberg
# Processing Record 15 of Set 12 | zhanaozen
# Processing Record 16 of Set 12 | moree
# Processing Record 17 of Set 12 | sitka
# Processing Record 18 of Set 12 | lompoc
# Processing Record 19 of Set 12 | ust-koksa
# Processing Record 20 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 12 | tallahassee
# Processing Record 22 of Set 12 | puerto escondido
# Processing Record 23 of Set 12 | champerico
# Processing Record 24 of Set 12 | henties bay
# Processing Record 25 of Set 12 | shemgang
# Processing Record 26 of Set 12 | sao joao de pirabas
# Processing Record 27 of Set 12 | likasi
# Processing Record 28 of Set 12 | norman wells
# Processing Record 29 of Set 12 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 12 | luderitz
# Processing Record 31 of Set 12 | mahuva
# Processing Record 32 of Set 12 | kingsland
# Processing Record 33 of Set 12 | tazovskiy
# Processing Record 34 of Set 12 | zhuhai
# Processing Record 35 of Set 12 | moroni
# Processing Record 36 of Set 12 | grand-lahou
# Processing Record 37 of Set 12 | mandalgovi
# Processing Record 38 of Set 12 | babu
# Processing Record 39 of Set 12 | troitsko-pechorsk
# Processing Record 40 of Set 12 | pafos
# Processing Record 41 of Set 12 | rumia
# Processing Record 42 of Set 12 | tarabuco
# Processing Record 43 of Set 12 | wajima
# Processing Record 44 of Set 12 | aykhal
# Processing Record 45 of Set 12 | yabelo
# Processing Record 46 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | morant bay
# Processing Record 49 of Set 12 | portland
# Processing Record 50 of Set 12 | iranshahr
# Processing Record 1 of Set 13 | dwarka
# Processing Record 2 of Set 13 | felanitx
# Processing Record 3 of Set 13 | hetauda
# Processing Record 4 of Set 13 | liwale
# Processing Record 5 of Set 13 | huejucar
# Processing Record 6 of Set 13 | ostrowiec swietokrzyski
# Processing Record 7 of Set 13 | pierre
# Processing Record 8 of Set 13 | chino valley
# Processing Record 9 of Set 13 | florianopolis
# Processing Record 10 of Set 13 | los palmitos
# Processing Record 11 of Set 13 | edgewater
# Processing Record 12 of Set 13 | evanston
# Processing Record 13 of Set 13 | altotonga
# Processing Record 14 of Set 13 | zaysan
# Processing Record 15 of Set 13 | kamina
# Processing Record 16 of Set 13 | moyale
# Processing Record 17 of Set 13 | elko
# Processing Record 18 of Set 13 | mehamn
# Processing Record 19 of Set 13 | sanmenxia
# Processing Record 20 of Set 13 | kuliyapitiya
# Processing Record 21 of Set 13 | limbdi
# Processing Record 22 of Set 13 | roswell
# Processing Record 23 of Set 13 | manacapuru
# Processing Record 24 of Set 13 | semme
# Processing Record 25 of Set 13 | salou
# Processing Record 26 of Set 13 | pergamino
# Processing Record 27 of Set 13 | shoranur
# Processing Record 28 of Set 13 | yumen
# Processing Record 29 of Set 13 | buala
# Processing Record 30 of Set 13 | lewisporte
# Processing Record 31 of Set 13 | ojinaga
# Processing Record 32 of Set 13 | rio gallegos
# Processing Record 33 of Set 13 | rajauri
# Processing Record 34 of Set 13 | atasu
# Processing Record 35 of Set 13 | bestobe
# Processing Record 36 of Set 13 | mildura
# Processing Record 37 of Set 13 | touros
# Processing Record 38 of Set 13 | elk river
# Processing Record 39 of Set 13 | carinhanha
# Processing Record 40 of Set 13 | urucara
# Processing Record 41 of Set 13 | thanh hoa
# Processing Record 42 of Set 13 | upata
# Processing Record 43 of Set 13 | san carlos
# Processing Record 44 of Set 13 | shakawe
# Processing Record 45 of Set 13 | floresta
# Processing Record 46 of Set 13 | santa cruz cabralia
# Processing Record 47 of Set 13 | qostanay
# Processing Record 48 of Set 13 | katherine
# Processing Record 49 of Set 13 | karlstad
# Processing Record 50 of Set 13 | belaya gora
# Processing Record 1 of Set 14 | senanga
# City not found. Skipping...
# Processing Record 2 of Set 14 | sibolga
# City not found. Skipping...
# Processing Record 3 of Set 14 | gornopravdinsk
# City not found. Skipping...
# Processing Record 4 of Set 14 | banda aceh
# City not found. Skipping...
# Processing Record 5 of Set 14 | gao
# City not found. Skipping...
# Processing Record 6 of Set 14 | cap malheureux
# City not found. Skipping...
# Processing Record 7 of Set 14 | malyye derbety
# City not found. Skipping...
# Processing Record 8 of Set 14 | waipawa
# City not found. Skipping...
# Processing Record 9 of Set 14 | lazaro cardenas
# City not found. Skipping...
# Processing Record 10 of Set 14 | wasilla
# City not found. Skipping...
# Processing Record 11 of Set 14 | palmer
# City not found. Skipping...
# Processing Record 12 of Set 14 | valdivia
# City not found. Skipping...
# Processing Record 13 of Set 14 | victor harbor
# City not found. Skipping...
# Processing Record 14 of Set 14 | voskresenskoye
# City not found. Skipping...
# Processing Record 15 of Set 14 | avera
# City not found. Skipping...
# Processing Record 16 of Set 14 | omboue
# City not found. Skipping...
# Processing Record 17 of Set 14 | grootfontein
# City not found. Skipping...
# Processing Record 18 of Set 14 | borogontsy
# City not found. Skipping...
# Processing Record 19 of Set 14 | korla
# City not found. Skipping...
# Processing Record 20 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 14 | esso
# City not found. Skipping...
# Processing Record 22 of Set 14 | dalmatovo
# City not found. Skipping...
# Processing Record 23 of Set 14 | makakilo city
# City not found. Skipping...
# Processing Record 24 of Set 14 | fare
# City not found. Skipping...
# Processing Record 25 of Set 14 | batagay-alyta
# City not found. Skipping...
# Processing Record 26 of Set 14 | byron bay
# City not found. Skipping...
# Processing Record 27 of Set 14 | thai binh
# City not found. Skipping...
# Processing Record 28 of Set 14 | staryy nadym
# City not found. Skipping...
# Processing Record 29 of Set 14 | deputatskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | cedar city
# City not found. Skipping...
# Processing Record 31 of Set 14 | soyo
# City not found. Skipping...
# Processing Record 32 of Set 14 | robertsport
# City not found. Skipping...
# Processing Record 33 of Set 14 | beringovskiy
# City not found. Skipping...
# Processing Record 34 of Set 14 | yertsevo
# City not found. Skipping...
# Processing Record 35 of Set 14 | oranjestad
# City not found. Skipping...
# Processing Record 36 of Set 14 | khonsar
# City not found. Skipping...
# Processing Record 37 of Set 14 | sur
# City not found. Skipping...
# Processing Record 38 of Set 14 | limon
# City not found. Skipping...
# Processing Record 39 of Set 14 | la libertad
# City not found. Skipping...
# Processing Record 40 of Set 14 | mutoko
# City not found. Skipping...
# Processing Record 41 of Set 14 | rawlins
# City not found. Skipping...
# Processing Record 42 of Set 14 | brae
# City not found. Skipping...
# Processing Record 43 of Set 14 | oktyabrskoye
# City not found. Skipping...
# Processing Record 44 of Set 14 | mana
# City not found. Skipping...
# Processing Record 45 of Set 14 | muroto
# City not found. Skipping...
# Processing Record 46 of Set 14 | bandar-e lengeh
# City not found. Skipping...
# Processing Record 47 of Set 14 | shingu
# City not found. Skipping...
# Processing Record 48 of Set 14 | baghdad
# City not found. Skipping...
# Processing Record 49 of Set 14 | plainview
# City not found. Skipping...
# Processing Record 50 of Set 14 | severnoye
# City not found. Skipping...
# Processing Record 1 of Set 15 | mezen
# Processing Record 2 of Set 15 | nador
# Processing Record 3 of Set 15 | kununurra
# Processing Record 4 of Set 15 | naze
# Processing Record 5 of Set 15 | diamantina
# Processing Record 6 of Set 15 | sotouboua
# Processing Record 7 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 8 of Set 15 | sivaki
# Processing Record 9 of Set 15 | the valley
# Processing Record 10 of Set 15 | traverse city
# Processing Record 11 of Set 15 | smithers
# Processing Record 12 of Set 15 | manga
# Processing Record 13 of Set 15 | bichura
# Processing Record 14 of Set 15 | praia da vitoria
# Processing Record 15 of Set 15 | iquitos
# Processing Record 16 of Set 15 | rjukan
# Processing Record 17 of Set 15 | tokomaru
# Processing Record 18 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 15 | abalak
# Processing Record 20 of Set 15 | chute-aux-outardes
# Processing Record 21 of Set 15 | tawang
# Processing Record 22 of Set 15 | kalmunai
# Processing Record 23 of Set 15 | mogadishu
# Processing Record 24 of Set 15 | jumla
# Processing Record 25 of Set 15 | churapcha
# Processing Record 26 of Set 15 | landau
# Processing Record 27 of Set 15 | marawi
# Processing Record 28 of Set 15 | isla mujeres
# Processing Record 29 of Set 15 | kanina
# Processing Record 30 of Set 15 | teahupoo
# Processing Record 31 of Set 15 | safford
# Processing Record 32 of Set 15 | schweinfurt
# Processing Record 33 of Set 15 | alofi
# Processing Record 34 of Set 15 | charlestown
# Processing Record 35 of Set 15 | santa rosa
# Processing Record 36 of Set 15 | lhokseumawe
# Processing Record 37 of Set 15 | sovetskiy
# Processing Record 38 of Set 15 | houma
# Processing Record 39 of Set 15 | dakar
# Processing Record 40 of Set 15 | onalaska
# Processing Record 41 of Set 15 | ati
# Processing Record 42 of Set 15 | tarsus
# Processing Record 43 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 15 | tigre
# Processing Record 45 of Set 15 | zhigansk
# Processing Record 46 of Set 15 | qidong
# Processing Record 47 of Set 15 | limbe
# Processing Record 48 of Set 15 | jardim
# Processing Record 49 of Set 15 | halifax
# Processing Record 50 of Set 15 | kuvandyk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 648

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Clyde River      CA  70.4692  -68.5914    -17.19        96          26
# 1  Severo-Kurilsk      RU  50.6789  156.1250     32.76        96         100
# 2        Havelock      US  34.8791  -76.9013     68.99        92          95
# 3      Butaritari      KI   3.0707  172.7902     82.56        72         100
# 4          Kodiak      US  57.7900 -152.4072      9.91        56           1
# 5       Hithadhoo      MV  -0.6000   73.0833     80.26        79          93
# 6       Busselton      AU -33.6500  115.3333     69.04        37          14
# 7            Lasa      IT  46.6166   10.7002     24.62        84          34
# 8          Hobart      AU -42.8794  147.3294     72.01        46          75
# 9     Tuktoyaktuk      CA  69.4541 -133.0374     -6.09        93         100
#
#    Wind Speed       Description
# 0        4.09  scattered clouds
# 1       24.14              snow
# 2       10.00   overcast clouds
# 3       17.83   overcast clouds
# 4       42.57         clear sky
# 5        7.47   overcast clouds
# 6       11.05        few clouds
# 7        8.59  scattered clouds
# 8        5.99     broken clouds
# 9       11.79   overcast clouds

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv("WeatherPy_Database.csv",index_label="City_ID")
